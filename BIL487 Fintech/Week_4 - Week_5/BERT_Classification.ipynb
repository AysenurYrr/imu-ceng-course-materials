# %%
import os

# %%
os.listdir()
# Out:
# ['.config', '.ipynb_checkpoints', 'AL_C-small - Copy.csv', 'sample_data']

# %%
import pandas as pd
import csv

# %%
df = pd.read_csv("/content/AL_C-small.csv", sep=';', engine='python',encoding="utf-8")

# %%
df.head()
# Out:
#    rowid      message_date         username  \
# 0  24383  01.10.2023 00:06          CgadaHi
# 1  26605  01.10.2023 00:18  LeonorO43665348
# 2  24382  01.10.2023 00:24   Akbuluttsonerr
# 3  24381  01.10.2023 00:49  yunusmiroglu34_
# 4  26573  01.10.2023 04:48      bomberosCBQ
#
#                                                about  \
# 0                            Halil İbrahim ceyhan ♥️
# 1                                                NaN
# 2  🅶🅰🅻🅰🆃🅰🆂🅰🆁🅰🆈 💛🦁♥️✍️📖🄰🄷🄼🄴🅃 🄺🄰🅈🄰 🎶📚 🎶🎶🎶🎶🎶🎤🅂🄴🄻🄳🄰 🄱...
# 3                                                NaN
# 4  Cuerpo Bomberos Quilpué   Abnegación y Discipl...
#
#                                       message_detail     tweet_id  \
# 0  HALİL İBRAHİM CEYHAN MENTİON ETKİNLİĞİ 📌HEDEF📌...  1,70823E+18
# 1  RT @GunesiTurk: ⛔️ DISPONIBLE ⛔️ PELICULA #Dar...  1,70823E+18
# 2  Geldim fener trolleri anlat  https://t.co/gHyE...  1,70823E+18
# 3  benim motivasyonum eleştiri mesleğe böyle başl...  1,70824E+18
# ...

# %%
df.count()
# Out:
# rowid                    29
# message_date             29
# username                 29
# about                    19
# message_detail           29
# tweet_id                 29
# account_creation_date    29
# followers                29
# token                    29
# gender                   29
# hashtag                   5
# image_url                 8
# internal_id              29
# language                 29
# location                 15
# message_url              29
# platform_type            29
# received_timestamp       29
# retweet_count            29
# retweet_id               29
# tweets                   29
# date                     29
# dtype: int64

# %%
# !pip install transformers

# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer= AutoTokenizer.from_pretrained("savasy/bert-turkish-text-classification")
model= AutoModelForSequenceClassification.from_pretrained("savasy/bert-turkish-text-classification")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
nlp=pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
nlp("bla bla")
# Out:
# [{'label': 'culture', 'score': 0.4753016233444214}]

# %%
nlp("bla bla")[0]['label']
# Out:
# 'culture'

# %%
import datetime
date1= datetime.datetime.now()
print("Start:" + str(date1))

for ind in df.index:
  #df.loc[index, 'sentiment']=nlp(df.loc[index, 'text'])[0]['label']
  category=nlp(df.loc[ind, 'message_detail'])[0]['label']
  df.loc[ind,'category']=category

date2= datetime.datetime.now()
print("End:"+ str(date2))
dateSon=date2-date1
print("Diff"+ str(dateSon))
# Out:
# Start:2024-10-20 21:01:23.798176
# End:2024-10-20 21:01:33.233448
# Diff0:00:09.435272

# %%
df.head()
# Out:
#    rowid      message_date         username  \
# 0  24383  01.10.2023 00:06          CgadaHi
# 1  26605  01.10.2023 00:18  LeonorO43665348
# 2  24382  01.10.2023 00:24   Akbuluttsonerr
# 3  24381  01.10.2023 00:49  yunusmiroglu34_
# 4  26573  01.10.2023 04:48      bomberosCBQ
#
#                                                about  \
# 0                            Halil İbrahim ceyhan ♥️
# 1                                                NaN
# 2  🅶🅰🅻🅰🆃🅰🆂🅰🆁🅰🆈 💛🦁♥️✍️📖🄰🄷🄼🄴🅃 🄺🄰🅈🄰 🎶📚 🎶🎶🎶🎶🎶🎤🅂🄴🄻🄳🄰 🄱...
# 3                                                NaN
# 4  Cuerpo Bomberos Quilpué   Abnegación y Discipl...
#
#                                       message_detail     tweet_id  \
# 0  HALİL İBRAHİM CEYHAN MENTİON ETKİNLİĞİ 📌HEDEF📌...  1,70823E+18
# 1  RT @GunesiTurk: ⛔️ DISPONIBLE ⛔️ PELICULA #Dar...  1,70823E+18
# 2  Geldim fener trolleri anlat  https://t.co/gHyE...  1,70823E+18
# 3  benim motivasyonum eleştiri mesleğe böyle başl...  1,70824E+18
# ...

# %%
file_name= "/content/son.csv"
df.to_csv(file_name, encoding='utf-8', index=False)
